# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import pandas as pd
##col_names=['age','job','marital','education','default','balance','housing','loan','contact','day','month','duration','compaign','pdays','previous','poutcome']
telco=pd.read_csv("C:\\Users\\User\\Desktop\\customer_final.csv")

#banks.head()
telco
print(telco.shape)
telco
# Out:
# (3998, 21)
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# 6     1452-KIOVK    Male              0      No        Yes      22
# 7     6713-OKOMC  Female              0      No         No      10
# 8     7892-POOKP  Female              0     Yes         No      28
# 9     6388-TABGU    Male              0      No        Yes      62
# 10    9763-GRSKD    Male              0     Yes        Yes      13
# 11    7469-LKBCI    Male              0      No         No      16
# 12    8091-TTVAX    Male              0     Yes         No      58
# ...

# %%
records = []
for i in range(1, 3998):
    records.append([str(telco.values[i, j]) for j in range(0, 20)])

# %%
print(type(records))
# Out:
# <class 'list'>

# %%
from apyori import apriori
association_rules = apriori(records, min_support=0.0045, min_confidence=0.2, min_lift=3, min_length=2)
association_results = list(association_rules)

# %%
print("There are {} Relation derived.".format(len(association_results)))
# Out:
# There are 684 Relation derived.

# %%
for i in range(0, len(association_results)):
    print(association_results[i][0])
# Out:
# frozenset({'No internet service', '19.4'})
# frozenset({'No internet service', '19.45'})
# frozenset({'No internet service', '19.55'})
# frozenset({'No internet service', '19.6'})
# frozenset({'No internet service', '19.65'})
# frozenset({'No internet service', '19.7'})
# frozenset({'No internet service', '19.8'})
# frozenset({'No internet service', '19.85'})
# frozenset({'No internet service', '19.9'})
# frozenset({'No internet service', '19.95'})
# frozenset({'No internet service', '20.0'})
# frozenset({'No internet service', '20.05'})
# frozenset({'No internet service', '20.1'})
# frozenset({'No internet service', '20.15'})
# frozenset({'No internet service', '20.25'})
# frozenset({'20.4', 'No internet service'})
# frozenset({'20.45', 'No internet service'})
# frozenset({'No internet service', '20.5'})
# frozenset({'69', 'Two year'})
# frozenset({'71', 'Two year'})
# frozenset({'Two year', '72'})
# frozenset({'No internet service', '0', '19.4'})
# ...

# %%
for item in association_results:
    # first index of the inner list
    # Contains base item and add item
    pair = item[0]
    items = [x for x in pair]
    print("Rule: " + items[0] + " -> " + items[1])

    # second index of the inner list
    print("Support: " + str(item[1]))

    # third index of the list located at 0th
    # of the third index of the inner list

    print("Confidence: " + str(item[2][0][2]))
    print("Lift: " + str(item[2][0][3]))
# Out:
# Rule: No internet service -> 19.4
# Support: 0.005003752814610958
# Confidence: 1.0
# Lift: 4.604838709677419
# Rule: No internet service -> 19.45
# Support: 0.005003752814610958
# Confidence: 1.0
# Lift: 4.604838709677419
# Rule: No internet service -> 19.55
# Support: 0.00600450337753315
# Confidence: 1.0
# Lift: 4.604838709677419
# Rule: No internet service -> 19.6
# Support: 0.00600450337753315
# Confidence: 1.0
# Lift: 4.604838709677419
# Rule: No internet service -> 19.65
# Support: 0.006254691018263698
# Confidence: 1.0
# Lift: 4.604838709677419
# Rule: No internet service -> 19.7
# Support: 0.006254691018263698
# Confidence: 1.0
# Lift: 4.604838709677419
# Rule: No internet service -> 19.8
# Support: 0.0047535651738804105
# Confidence: 1.0
# Lift: 4.604838709677419
# Rule: No internet service -> 19.85
# Support: 0.00725544158118589
# Confidence: 1.0
# Lift: 4.604838709677419
# Rule: No internet service -> 19.9
# Support: 0.00600450337753315
# Confidence: 1.0
# ...
